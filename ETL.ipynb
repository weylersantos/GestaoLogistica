# %% [markdown]
# ### ***Importando as bibliotecas e o Dataset***

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel('BD_Logistica.xlsx')
df.head()
# Out:
#   Nº Pedido               Cliente-Motorista Data Emissão Pedido  \
# 0        A3            WALMART-FELIPE SILVA          2019-01-27
# 1        A4   MAGAZINE LUIZA-TÚLIO SILVEIRA          2019-01-28
# 2        A7  MAGAZINE LUIZA-VALDIR ESPINOSA          2019-02-04
# 3       A12     MAGAZINE LUIZA-MARCOS LEROY          2019-02-18
# 4       A15             WALMART-LUIZ PARDAL          2019-02-21
#
#   Data Entrega Prevista Destino  Itens  R$ Faturados Saída para Entrega  \
# 0            2019-02-06      SP      3         139.5         2019-01-29
# 1            2019-02-07      RJ      4         134.4         2019-02-09
# 2            2019-02-14      SP      5          79.5         2019-02-07
# 3            2019-02-28      SP     20         326.0         2019-02-23
# 4            2019-03-03      RJ     12         597.6         2019-02-28
#
#   Data Entrega Real   Qtd Devolução  Mot. Devolução  Dias Para Entrega  \
# 0        2019-02-03               0      S/ Devolu.                  7
# 1        2019-02-12               0      S/ Devolu.                 15
# 2        2019-02-14               1  Produto Errado                 10
# 3        2019-02-25              11  Produto Errado                  7
# 4        2019-03-07               0      S/ Devolu.                 14
#
#      Status
# 0  No Prazo
# 1  Atrasado
# 2  No Prazo
# 3  No Prazo
# 4  Atrasado

# %% [markdown]
# ### ***Inspecionando os dados***

# %%
df.columns
# Out:
# Index(['Nº Pedido', 'Cliente-Motorista', 'Data Emissão Pedido',
#        'Data Entrega Prevista', 'Destino', 'Itens', 'R$ Faturados',
#        'Saída para Entrega', 'Data Entrega Real', ' Qtd Devolução',
#        'Mot. Devolução', 'Dias Para Entrega', 'Status'],
#       dtype='object')

# %%
df.describe()
# Out:
#              Itens  R$ Faturados   Qtd Devolução  Dias Para Entrega
# count  4282.000000   4282.000000     4282.000000        4282.000000
# mean     10.492994    339.038230        1.861747          13.120738
# std       5.802526    244.817324        2.421298           3.816712
# min       1.000000     15.000000        0.000000           3.000000
# 25%       5.000000    144.900000        1.000000          10.000000
# 50%      11.000000    279.000000        1.000000          13.000000
# 75%      15.000000    505.600000        2.000000          16.000000
# max      20.000000   1020.000000       19.000000          20.000000

# %%
df.dtypes
# Out:
# Nº Pedido                        object
# Cliente-Motorista                object
# Data Emissão Pedido      datetime64[ns]
# Data Entrega Prevista    datetime64[ns]
# Destino                          object
# Itens                             int64
# R$ Faturados                    float64
# Saída para Entrega       datetime64[ns]
# Data Entrega Real        datetime64[ns]
#  Qtd Devolução                    int64
# Mot. Devolução                   object
# Dias Para Entrega                 int64
# Status                           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Nº Pedido                0
# Cliente-Motorista        0
# Data Emissão Pedido      0
# Data Entrega Prevista    0
# Destino                  0
# Itens                    0
# R$ Faturados             0
# Saída para Entrega       0
# Data Entrega Real        0
#  Qtd Devolução           0
# Mot. Devolução           0
# Dias Para Entrega        0
# Status                   0
# dtype: int64

# %% [markdown]
# ### ***Tratando os dados***

# %%
#Removendo espaços ao final ou inicio do nome das colunas
df.columns = df.columns.str.strip()

# %%
#Alterando o formato de data nas respectivas coluns
def format_data(x):
    data = x.dt.strftime('%d/%m/%Y')
    return data

df[['Data Emissão Pedido', 'Data Entrega Prevista',
         'Saída para Entrega', 'Data Entrega Real']] = df[['Data Emissão Pedido', 'Data Entrega Prevista',
         'Saída para Entrega', 'Data Entrega Real']].apply(lambda x: format_data(x))

# %%
#Separando em duas colunas os registros de Empresa e Motorista
def get_empresa(x):
  empresa = x.split('-')[0].title()
  return empresa

def get_motorista(x):
  motorista = x.split('-')[1].title()
  return motorista

df['Empresa'] = df['Cliente-Motorista'].apply(lambda x: get_empresa(x))
df['Motorista'] = df['Cliente-Motorista'].apply(lambda x: get_motorista(x))

df.drop(columns='Cliente-Motorista', axis=1, inplace=True)

df.head()
# Out:
#   Nº Pedido Data Emissão Pedido Data Entrega Prevista Destino  Itens  \
# 0        A3          27/01/2019            06/02/2019      SP      3
# 1        A4          28/01/2019            07/02/2019      RJ      4
# 2        A7          04/02/2019            14/02/2019      SP      5
# 3       A12          18/02/2019            28/02/2019      SP     20
# 4       A15          21/02/2019            03/03/2019      RJ     12
#
#    R$ Faturados Saída para Entrega Data Entrega Real  Qtd Devolução  \
# 0         139.5         29/01/2019        03/02/2019              0
# 1         134.4         09/02/2019        12/02/2019              0
# 2          79.5         07/02/2019        14/02/2019              1
# 3         326.0         23/02/2019        25/02/2019             11
# 4         597.6         28/02/2019        07/03/2019              0
#
#    Mot. Devolução  Dias Para Entrega    Status         Empresa  \
# 0      S/ Devolu.                  7  No Prazo         Walmart
# 1      S/ Devolu.                 15  Atrasado  Magazine Luiza
# 2  Produto Errado                 10  No Prazo  Magazine Luiza
# 3  Produto Errado                  7  No Prazo  Magazine Luiza
# 4      S/ Devolu.                 14  Atrasado         Walmart
#
#          Motorista
# 0     Felipe Silva
# 1   Túlio Silveira
# 2  Valdir Espinosa
# 3     Marcos Leroy
# 4      Luiz Pardal

# %%
#Reorganizando as colunas
df = df[['Nº Pedido','Empresa', 'Motorista','Data Emissão Pedido', 'Data Entrega Prevista', 'Destino',
       'Itens', 'R$ Faturados', 'Saída para Entrega', 'Data Entrega Real',
       'Qtd Devolução', 'Mot. Devolução', 'Dias Para Entrega', 'Status']]
df.head()
# Out:
#   Nº Pedido         Empresa        Motorista Data Emissão Pedido  \
# 0        A3         Walmart     Felipe Silva          27/01/2019
# 1        A4  Magazine Luiza   Túlio Silveira          28/01/2019
# 2        A7  Magazine Luiza  Valdir Espinosa          04/02/2019
# 3       A12  Magazine Luiza     Marcos Leroy          18/02/2019
# 4       A15         Walmart      Luiz Pardal          21/02/2019
#
#   Data Entrega Prevista Destino  Itens  R$ Faturados Saída para Entrega  \
# 0            06/02/2019      SP      3         139.5         29/01/2019
# 1            07/02/2019      RJ      4         134.4         09/02/2019
# 2            14/02/2019      SP      5          79.5         07/02/2019
# 3            28/02/2019      SP     20         326.0         23/02/2019
# 4            03/03/2019      RJ     12         597.6         28/02/2019
#
#   Data Entrega Real  Qtd Devolução  Mot. Devolução  Dias Para Entrega  \
# 0        03/02/2019              0      S/ Devolu.                  7
# 1        12/02/2019              0      S/ Devolu.                 15
# 2        14/02/2019              1  Produto Errado                 10
# 3        25/02/2019             11  Produto Errado                  7
# 4        07/03/2019              0      S/ Devolu.                 14
#
#      Status
# 0  No Prazo
# 1  Atrasado
# 2  No Prazo
# 3  No Prazo
# 4  Atrasado

# %%
# Renomeando valores que estão no dataframe
df.replace({'BH': 'MG',
            'S/ Devolu.': 'Sem Devolução'}, inplace=True)

df.head()
# Out:
#   Nº Pedido         Empresa        Motorista Data Emissão Pedido  \
# 0        A3         Walmart     Felipe Silva          27/01/2019
# 1        A4  Magazine Luiza   Túlio Silveira          28/01/2019
# 2        A7  Magazine Luiza  Valdir Espinosa          04/02/2019
# 3       A12  Magazine Luiza     Marcos Leroy          18/02/2019
# 4       A15         Walmart      Luiz Pardal          21/02/2019
#
#   Data Entrega Prevista Destino  Itens  R$ Faturados Saída para Entrega  \
# 0            06/02/2019      SP      3         139.5         29/01/2019
# 1            07/02/2019      RJ      4         134.4         09/02/2019
# 2            14/02/2019      SP      5          79.5         07/02/2019
# 3            28/02/2019      SP     20         326.0         23/02/2019
# 4            03/03/2019      RJ     12         597.6         28/02/2019
#
#   Data Entrega Real  Qtd Devolução  Mot. Devolução  Dias Para Entrega  \
# 0        03/02/2019              0   Sem Devolução                  7
# 1        12/02/2019              0   Sem Devolução                 15
# 2        14/02/2019              1  Produto Errado                 10
# 3        25/02/2019             11  Produto Errado                  7
# 4        07/03/2019              0   Sem Devolução                 14
#
#      Status
# 0  No Prazo
# 1  Atrasado
# 2  No Prazo
# 3  No Prazo
# 4  Atrasado

# %% [markdown]
# ### ***Web Scraping***

# %% [markdown]
# - O objetivo dessa etapa é justamente identificar o estado e região de cada entrega. Para executar essa tarefa iremos extrair os dados da fonte abaixo:
#
# https://www.todamateria.com.br/siglas-estados-brasileiros/

# %%
from bs4 import BeautifulSoup as bs
import requests

url = 'https://www.todamateria.com.br/siglas-estados-brasileiros/'

#Inspecionando a página
r = requests.get(url)
soup = bs(r.text, 'html.parser')

#Tag que iremos utilizar para fazer a extração
results = soup.find_all('tr')

# %%
# Criando um dataframe com informações de cada estado do Brasil
estados_list = []

for rows in results:
  info = rows.text
  estado = {
      'Estado': info.split('\n')[1],
      'Sigla': info.split('\n')[2],
      'Regiao': info.split('\n')[3].split()[-1]
  }
  estados_list.append(estado)

del estados_list[:1]

estados = pd.DataFrame(estados_list)

estados
# Out:
#                  Estado Sigla        Regiao
# 0                  Acre    AC         Norte
# 1               Alagoas    AL      Nordeste
# 2                 Amapá    AP         Norte
# 3              Amazonas    AM         Norte
# 4                 Bahia    BA      Nordeste
# 5                 Ceará    CE      Nordeste
# 6      Distrito Federal    DF  Centro-Oeste
# 7        Espírito Santo    ES       Sudeste
# 8                 Goiás    GO  Centro-Oeste
# 9              Maranhão    MA      Nordeste
# 10          Mato Grosso    MT  Centro-Oeste
# 11   Mato Grosso do Sul    MS  Centro-Oeste
# 12         Minas Gerais    MG       Sudeste
# 13                 Pará    PA         Norte
# 14              Paraíba    PB      Nordeste
# 15               Paraná    PR           Sul
# 16           Pernambuco    PE      Nordeste
# 17                Piauí    PI      Nordeste
# 18       Rio de Janeiro    RJ       Sudeste
# 19  Rio Grande do Norte    RN      Nordeste
# 20    Rio Grande do Sul    RS           Sul
# 21             Rondônia    RO         Norte
# 22              Roraima    RR         Norte
# 23       Santa Catarina    SC           Sul
# 24            São Paulo    SP       Sudeste
# 25              Sergipe    SE      Nordeste
# 26            Tocantins    TO         Norte

# %% [markdown]
# ### ***Unir os dois dataframes para exportação***

# %% [markdown]
#  - Como uma alternativa para caso seja necessário escalonar essa base de dados, aumentando exponencialmente a quantidade de dados, iremos exportar o dataframe em formato parquet. Desta forma, iremos ter uma importação mais rápida caso seja necessário fazer uma leitura desse arquivo futuramente.

# %%
logistica = df.merge(estados, how='left', left_on='Destino', right_on='Sigla')
logistica.drop(columns=['Sigla'], inplace=True)

# %%
#Reorganizando as colunas para uma melhor vizualização
logistica = logistica[['Nº Pedido', 'Empresa', 'Motorista', 'Data Emissão Pedido',
       'Saída para Entrega','Destino', 'Estado', 'Regiao', 'Itens', 
       'R$ Faturados','Data Entrega Prevista','Data Entrega Real', 
       'Qtd Devolução','Mot. Devolução', 'Dias Para Entrega', 'Status']]

#Confirmando os tipos de dados para cada coluna
logistica.dtypes
# Out:
# Nº Pedido                 object
# Empresa                   object
# Motorista                 object
# Data Emissão Pedido       object
# Saída para Entrega        object
# Destino                   object
# Estado                    object
# Regiao                    object
# Itens                      int64
# R$ Faturados             float64
# Data Entrega Prevista     object
# Data Entrega Real         object
# Qtd Devolução              int64
# Mot. Devolução            object
# Dias Para Entrega          int64
# Status                    object
# dtype: object

# %%
logistica.to_parquet('Dados de Logistica.parquet', engine='pyarrow')

# %% [markdown]
# ### ***Conclusão***

# %% [markdown]
# - Nesse momento já temos um novo dataset com os devidos tratamentos e a inserção de novas informações para enriquecer ainda mais futuras análises.
